# %%
#Estimating the total compensation to be provided to an employee
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean

# %%
df=pd.read_csv('train_set.csv')
df
# Out:
#         Year  OGC                                        OG   DC  \
# 0       2015    4                          Community Health  DPH
# 1       2013    4                          Community Health  DPH
# 2       2015    6          General Administration & Finance  ASR
# 3       2016    1                         Public Protection  POL
# 4       2013    2   Public Works, Transportation & Commerce  HHP
# ...      ...  ...                                       ...  ...
# 287831  2016    3  Human Welfare & Neighborhood Development  DSS
# 287832  2015    5                      Culture & Recreation  LIB
# 287833  2014    2   Public Works, Transportation & Commerce  HHP
# 287834  2013    1                         Public Protection  JUV
# 287835  2015    4                          Community Health  DPH
#
#                       Dept   UC  \
# 0            Public Health  250
# 1            Public Health   39
# 2        Assessor/Recorder   21
# 3                   Police  911
# ...

# %%
 df.shape
# Out:
# (287836, 15)

# %%
features = df[['Salaries', 'Overtime', 'H/D']]  
target = df['Total_Compensation']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = mse**0.5
print('Root Mean Squared Error:', rmse)
# Out:
# Root Mean Squared Error: 7658.0975763551205

# %%
all_predictions = model.predict(features)
df['Estimated_Total_Compensation'] = all_predictions

# %%
all_predictions
# Out:
# array([ 16273.52793025, 115143.85775768, 145132.27110416, ...,
#        150908.80104775,  23752.18015223, 157313.15026718])
